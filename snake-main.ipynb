# %% [markdown]
# # Q-learning Snake Game - Surya Sunkari

# %% [markdown]
# <img src="snake_game.jpg" width="300"/>

# %% [markdown]
# #### Imports

# %%
# you will need pygame installed
# !pip install pygame
# Out:
# Requirement already satisfied: pygame in c:\python311\lib\site-packages (2.6.0)
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pygame
import random
import numpy as np
import matplotlib.pyplot as plt

import pickle as pkl
import itertools

# the environment is provided in game_loop.py
from game_loop import *

# %% [markdown]
# ### Game States
# For Q-Learning, the agent needs to keep a Q-Table of game states. To keep the number of possible game states manageable, we will define the game state as a combination of:
# * Horizontal orientation from the food - is the food currently to the left or the right of the snake's head? (-1: left, 0: same, 1: right)
# * Vertical orientation from the food - is the food currently above or below the snake's head? (-1: below, 0: same, 1: above)
# * What are in the squares adjacent to the snake's head - are there walls or snake tail in these squares? (1 indicates something is there, 0 indicates it is open)
#
# The environment (which is in the provided `game_loop.py` file) will provide this state in the form of two tuples:
# - The first tuple will contain (relative horizontal orientation to food, relative vertical orientation to food).
# - The second tuple will contain the squares surrounding the snake's head in the form of (up, down, left, right) where a 1 indicates wall or tail is in that square and 0 indicates that square is open.
#
# ### Snake Agent
# Below is the class for the SnakeAgent that will learn to play the game, using Q-Learning.
#
# Here is a description of the methods:
# * `__init__`: The constructor sets up some constants and sets the learning parameter values. It also calls init_qtable to initialize the Q-Table.
# * `init_qtable`: Initializes the Q-Table. The `qtable` is implemented as a dictionary of state -> list of four Q-Values, representing the four action choices of [left, right, up, down].
# * `save` and `load`: Saves the Q-Values (via pickle) so the agent can be re-loaded later via load.
#
# These methods will be called by the `game_loop.py` file:
# * `act`: This method is responsible for selecting an action based on the current state.
# * `update`: This where the Q-values get updated based on the agent's actions and rewards during gameplay.

# %%
class SnakeAgent(object):

    def __init__(self, DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE):

        self.ACTION_STRING_MAP = {0: "left", 1: "right", 2: "up", 3: "down"}

        # Learning parameters
        self.epsilon = 0.1 # exploration rate
        self.alpha = 0.4 # learning rate
        self.gamma = 0.5 # discount factor

        # Initialize the Q-Table
        self.init_qtable()
        
        # State/Action history
        self.curr_state = None
        self.curr_act = None
        self.curr_dist_from_food = 1000

    def init_qtable(self):
        # Initialize the qtable to all 0s
        self.qtable = {}
        REL_Y = [-1, 0, 1] # [below, same, above]
        REL_X = [-1, 0, 1] # [left, same, right]
        SURROUNDINGS = list(itertools.product(*[[0,1]] * 4)) # [0, 1] possibilities for surrounding block in each direction
        for y in REL_X:
            for x in REL_Y:
                for s in SURROUNDINGS:
                    self.qtable[QState((x, y), tuple(s))] = [0, 0, 0, 0] # q values for actions [left, right, up, down]

    def load(self, path="qtable.pkl"):
        return pkl.load(open(path, "rb"))

    def save(self, path="qtable.pkl"):
        pkl.dump(self.qtable, open(path, "wb"))
        
    def act(self, state):
        selected_action = -1
        rand_value = random.random()
        if rand_value < self.epsilon:
            selected_action = random.choice([0, 1, 2, 3])
        else:
            potential_actions = self.qtable[state]
            selected_action = np.argmax(potential_actions)
        
        self.curr_state = state
        self.curr_act = selected_action
                   
        return self.ACTION_STRING_MAP[selected_action]
    
    def update(self, game_over, dist_from_food, new_state): 
        reward = 0
        if game_over:
            reward = -25
        else:
            if dist_from_food < self.curr_dist_from_food:
                reward = 10
            else:
                reward = -10
        self.curr_dist_from_food = dist_from_food
        
        old_q_val = self.qtable[self.curr_state][self.curr_act]
        td = reward + self.gamma * np.max(self.qtable[new_state]) - old_q_val
        new_q_val = old_q_val + self.alpha * td
        
        self.qtable[self.curr_state][self.curr_act] = new_q_val

# %% [markdown]
# ### Game Loop (only run if you want to retrain model)
# The code in this cell will kick off the game, using the SnakeAgent, and will let the agent play for the specified number of episodes (300), keeping track of the scores as the agent learns how to play.

# %%
pygame.init()

BLOCK_SIZE = 10 
DIS_WIDTH = 600
DIS_HEIGHT = 500
FRAMESPEED = 50000 # extremely fast frame speed for training purposes.
NUM_EPISODES = 300

#create a SnakeAgent
agent = SnakeAgent(DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE)

game_count = 1
max_score = 0
scores = []

# loop for specified number of episodes
for i in range(NUM_EPISODES):
    # use an exponentially decaying epsilon rate
    if game_count > 100:
        agent.epsilon = max(.003, agent.epsilon * .98)
    else:
        agent.epsilon = .1
        
    # Start the game
    # (To turn off the game visualizations, you can set draw=False)
    score = GameLoop(agent, DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE, FRAMESPEED, draw=True)
    
    scores.append(score)
    max_score = max(max_score, score)
    print(f"Games: {game_count}; Score: {score}; Max Score: {max_score}") # Output results of each game to console to monitor as agent is training
    game_count += 1

agent.save()
print("Save Qvals")
pygame.quit()
# Out:
# Games: 1; Score: 1; Max Score: 1
# Games: 2; Score: 1; Max Score: 1
# Games: 3; Score: 1; Max Score: 1
# Games: 4; Score: 1; Max Score: 1
# Games: 5; Score: 1; Max Score: 1
# Games: 6; Score: 1; Max Score: 1
# Games: 7; Score: 1; Max Score: 1
# Games: 8; Score: 1; Max Score: 1
# Games: 9; Score: 1; Max Score: 1
# Games: 10; Score: 1; Max Score: 1
# Games: 11; Score: 1; Max Score: 1
# Games: 12; Score: 1; Max Score: 1
# Games: 13; Score: 1; Max Score: 1
# Games: 14; Score: 1; Max Score: 1
# Games: 15; Score: 1; Max Score: 1
# Games: 16; Score: 1; Max Score: 1
# Games: 17; Score: 1; Max Score: 1
# Games: 18; Score: 1; Max Score: 1
# Games: 19; Score: 1; Max Score: 1
# Games: 20; Score: 5; Max Score: 5
# Games: 21; Score: 3; Max Score: 5
# Games: 22; Score: 2; Max Score: 5
# Games: 23; Score: 2; Max Score: 5
# Games: 24; Score: 2; Max Score: 5
# Games: 25; Score: 1; Max Score: 5
# Games: 26; Score: 1; Max Score: 5
# Games: 27; Score: 2; Max Score: 5
# Games: 28; Score: 1; Max Score: 5
# Games: 29; Score: 4; Max Score: 5
# Games: 30; Score: 1; Max Score: 5
# Games: 31; Score: 1; Max Score: 5
# Games: 32; Score: 1; Max Score: 5
# Games: 33; Score: 2; Max Score: 5
# Games: 34; Score: 1; Max Score: 5
# Games: 35; Score: 1; Max Score: 5
# Games: 36; Score: 1; Max Score: 5
# Games: 37; Score: 1; Max Score: 5
# Games: 38; Score: 2; Max Score: 5
# Games: 39; Score: 1; Max Score: 5
# Games: 40; Score: 2; Max Score: 5
# Games: 41; Score: 2; Max Score: 5
# Games: 42; Score: 2; Max Score: 5
# Games: 43; Score: 2; Max Score: 5
# Games: 44; Score: 5; Max Score: 5
# Games: 45; Score: 2; Max Score: 5
# Games: 46; Score: 1; Max Score: 5
# Games: 47; Score: 1; Max Score: 5
# Games: 48; Score: 2; Max Score: 5
# Games: 49; Score: 1; Max Score: 5
# Games: 50; Score: 1; Max Score: 5
# Games: 51; Score: 1; Max Score: 5
# Games: 52; Score: 1; Max Score: 5
# Games: 53; Score: 2; Max Score: 5
# Games: 54; Score: 3; Max Score: 5
# Games: 55; Score: 3; Max Score: 5
# Games: 56; Score: 2; Max Score: 5
# Games: 57; Score: 2; Max Score: 5
# Games: 58; Score: 1; Max Score: 5
# Games: 59; Score: 2; Max Score: 5
# Games: 60; Score: 1; Max Score: 5
# Games: 61; Score: 1; Max Score: 5
# Games: 62; Score: 1; Max Score: 5
# Games: 63; Score: 3; Max Score: 5
# Games: 64; Score: 2; Max Score: 5
# Games: 65; Score: 2; Max Score: 5
# Games: 66; Score: 1; Max Score: 5
# Games: 67; Score: 3; Max Score: 5
# Games: 68; Score: 2; Max Score: 5
# Games: 69; Score: 2; Max Score: 5
# Games: 70; Score: 3; Max Score: 5
# Games: 71; Score: 2; Max Score: 5
# Games: 72; Score: 1; Max Score: 5
# Games: 73; Score: 1; Max Score: 5
# Games: 74; Score: 1; Max Score: 5
# Games: 75; Score: 2; Max Score: 5
# Games: 76; Score: 2; Max Score: 5
# Games: 77; Score: 1; Max Score: 5
# Games: 78; Score: 1; Max Score: 5
# Games: 79; Score: 4; Max Score: 5
# Games: 80; Score: 1; Max Score: 5
# Games: 81; Score: 1; Max Score: 5
# Games: 82; Score: 1; Max Score: 5
# Games: 83; Score: 1; Max Score: 5
# Games: 84; Score: 2; Max Score: 5
# Games: 85; Score: 2; Max Score: 5
# Games: 86; Score: 1; Max Score: 5
# Games: 87; Score: 1; Max Score: 5
# Games: 88; Score: 1; Max Score: 5
# Games: 89; Score: 1; Max Score: 5
# Games: 90; Score: 3; Max Score: 5
# Games: 91; Score: 3; Max Score: 5
# Games: 92; Score: 2; Max Score: 5
# Games: 93; Score: 1; Max Score: 5
# Games: 94; Score: 1; Max Score: 5
# Games: 95; Score: 1; Max Score: 5
# Games: 96; Score: 1; Max Score: 5
# Games: 97; Score: 1; Max Score: 5
# Games: 98; Score: 2; Max Score: 5
# Games: 99; Score: 2; Max Score: 5
# Games: 100; Score: 1; Max Score: 5
# Games: 101; Score: 2; Max Score: 5
# Games: 102; Score: 1; Max Score: 5
# Games: 103; Score: 2; Max Score: 5
# Games: 104; Score: 4; Max Score: 5
# Games: 105; Score: 1; Max Score: 5
# Games: 106; Score: 1; Max Score: 5
# Games: 107; Score: 1; Max Score: 5
# Games: 108; Score: 1; Max Score: 5
# Games: 109; Score: 1; Max Score: 5
# Games: 110; Score: 2; Max Score: 5
# Games: 111; Score: 4; Max Score: 5
# Games: 112; Score: 1; Max Score: 5
# Games: 113; Score: 2; Max Score: 5
# Games: 114; Score: 3; Max Score: 5
# Games: 115; Score: 3; Max Score: 5
# Games: 116; Score: 2; Max Score: 5
# Games: 117; Score: 3; Max Score: 5
# Games: 118; Score: 2; Max Score: 5
# Games: 119; Score: 1; Max Score: 5
# Games: 120; Score: 2; Max Score: 5
# Games: 121; Score: 1; Max Score: 5
# Games: 122; Score: 1; Max Score: 5
# Games: 123; Score: 1; Max Score: 5
# Games: 124; Score: 3; Max Score: 5
# Games: 125; Score: 1; Max Score: 5
# Games: 126; Score: 1; Max Score: 5
# Games: 127; Score: 3; Max Score: 5
# Games: 128; Score: 6; Max Score: 6
# Games: 129; Score: 1; Max Score: 6
# Games: 130; Score: 2; Max Score: 6
# Games: 131; Score: 1; Max Score: 6
# Games: 132; Score: 7; Max Score: 7
# Games: 133; Score: 3; Max Score: 7
# Games: 134; Score: 3; Max Score: 7
# Games: 135; Score: 1; Max Score: 7
# Games: 136; Score: 2; Max Score: 7
# Games: 137; Score: 3; Max Score: 7
# Games: 138; Score: 4; Max Score: 7
# Games: 139; Score: 5; Max Score: 7
# Games: 140; Score: 3; Max Score: 7
# Games: 141; Score: 1; Max Score: 7
# Games: 142; Score: 1; Max Score: 7
# Games: 143; Score: 2; Max Score: 7
# Games: 144; Score: 1; Max Score: 7
# Games: 145; Score: 4; Max Score: 7
# Games: 146; Score: 5; Max Score: 7
# Games: 147; Score: 8; Max Score: 8
# Games: 148; Score: 1; Max Score: 8
# Games: 149; Score: 3; Max Score: 8
# Games: 150; Score: 8; Max Score: 8
# Games: 151; Score: 3; Max Score: 8
# Games: 152; Score: 2; Max Score: 8
# Games: 153; Score: 3; Max Score: 8
# Games: 154; Score: 6; Max Score: 8
# Games: 155; Score: 1; Max Score: 8
# Games: 156; Score: 2; Max Score: 8
# Games: 157; Score: 3; Max Score: 8
# Games: 158; Score: 3; Max Score: 8
# Games: 159; Score: 7; Max Score: 8
# Games: 160; Score: 1; Max Score: 8
# Games: 161; Score: 8; Max Score: 8
# Games: 162; Score: 4; Max Score: 8
# Games: 163; Score: 1; Max Score: 8
# Games: 164; Score: 2; Max Score: 8
# Games: 165; Score: 4; Max Score: 8
# Games: 166; Score: 8; Max Score: 8
# Games: 167; Score: 5; Max Score: 8
# Games: 168; Score: 7; Max Score: 8
# Games: 169; Score: 19; Max Score: 19
# Games: 170; Score: 2; Max Score: 19
# Games: 171; Score: 5; Max Score: 19
# Games: 172; Score: 4; Max Score: 19
# Games: 173; Score: 9; Max Score: 19
# Games: 174; Score: 6; Max Score: 19
# Games: 175; Score: 2; Max Score: 19
# Games: 176; Score: 1; Max Score: 19
# Games: 177; Score: 3; Max Score: 19
# Games: 178; Score: 10; Max Score: 19
# Games: 179; Score: 5; Max Score: 19
# Games: 180; Score: 1; Max Score: 19
# Games: 181; Score: 4; Max Score: 19
# Games: 182; Score: 2; Max Score: 19
# Games: 183; Score: 11; Max Score: 19
# Games: 184; Score: 3; Max Score: 19
# Games: 185; Score: 2; Max Score: 19
# Games: 186; Score: 9; Max Score: 19
# Games: 187; Score: 1; Max Score: 19
# Games: 188; Score: 19; Max Score: 19
# Games: 189; Score: 18; Max Score: 19
# Games: 190; Score: 3; Max Score: 19
# Games: 191; Score: 1; Max Score: 19
# Games: 192; Score: 3; Max Score: 19
# Games: 193; Score: 4; Max Score: 19
# Games: 194; Score: 3; Max Score: 19
# Games: 195; Score: 1; Max Score: 19
# Games: 196; Score: 12; Max Score: 19
# Games: 197; Score: 14; Max Score: 19
# Games: 198; Score: 22; Max Score: 22
# Games: 199; Score: 9; Max Score: 22
# Games: 200; Score: 5; Max Score: 22
# Games: 201; Score: 9; Max Score: 22
# Games: 202; Score: 16; Max Score: 22
# Games: 203; Score: 17; Max Score: 22
# Games: 204; Score: 22; Max Score: 22
# Games: 205; Score: 12; Max Score: 22
# Games: 206; Score: 2; Max Score: 22
# Games: 207; Score: 1; Max Score: 22
# Games: 208; Score: 3; Max Score: 22
# Games: 209; Score: 4; Max Score: 22
# Games: 210; Score: 1; Max Score: 22
# Games: 211; Score: 4; Max Score: 22
# Games: 212; Score: 4; Max Score: 22
# Games: 213; Score: 9; Max Score: 22
# Games: 214; Score: 4; Max Score: 22
# Games: 215; Score: 3; Max Score: 22
# Games: 216; Score: 18; Max Score: 22
# Games: 217; Score: 1; Max Score: 22
# Games: 218; Score: 12; Max Score: 22
# Games: 219; Score: 5; Max Score: 22
# Games: 220; Score: 3; Max Score: 22
# Games: 221; Score: 5; Max Score: 22
# Games: 222; Score: 1; Max Score: 22
# Games: 223; Score: 9; Max Score: 22
# Games: 224; Score: 13; Max Score: 22
# Games: 225; Score: 12; Max Score: 22
# Games: 226; Score: 1; Max Score: 22
# Games: 227; Score: 8; Max Score: 22
# Games: 228; Score: 19; Max Score: 22
# Games: 229; Score: 15; Max Score: 22
# Games: 230; Score: 5; Max Score: 22
# Games: 231; Score: 14; Max Score: 22
# Games: 232; Score: 8; Max Score: 22
# Games: 233; Score: 14; Max Score: 22
# Games: 234; Score: 19; Max Score: 22
# Games: 235; Score: 17; Max Score: 22
# Games: 236; Score: 5; Max Score: 22
# Games: 237; Score: 3; Max Score: 22
# Games: 238; Score: 13; Max Score: 22
# Games: 239; Score: 8; Max Score: 22
# Games: 240; Score: 10; Max Score: 22
# Games: 241; Score: 5; Max Score: 22
# Games: 242; Score: 4; Max Score: 22
# Games: 243; Score: 8; Max Score: 22
# Games: 244; Score: 14; Max Score: 22
# Games: 245; Score: 8; Max Score: 22
# Games: 246; Score: 36; Max Score: 36
# Games: 247; Score: 11; Max Score: 36
# Games: 248; Score: 7; Max Score: 36
# Games: 249; Score: 34; Max Score: 36
# Games: 250; Score: 12; Max Score: 36
# Games: 251; Score: 28; Max Score: 36
# Games: 252; Score: 1; Max Score: 36
# Games: 253; Score: 2; Max Score: 36
# Games: 254; Score: 25; Max Score: 36
# Games: 255; Score: 10; Max Score: 36
# Games: 256; Score: 18; Max Score: 36
# Games: 257; Score: 2; Max Score: 36
# Games: 258; Score: 30; Max Score: 36
# Games: 259; Score: 19; Max Score: 36
# Games: 260; Score: 13; Max Score: 36
# Games: 261; Score: 11; Max Score: 36
# Games: 262; Score: 23; Max Score: 36
# Games: 263; Score: 21; Max Score: 36
# Games: 264; Score: 5; Max Score: 36
# Games: 265; Score: 9; Max Score: 36
# Games: 266; Score: 25; Max Score: 36
# Games: 267; Score: 16; Max Score: 36
# Games: 268; Score: 1; Max Score: 36
# Games: 269; Score: 1; Max Score: 36
# Games: 270; Score: 25; Max Score: 36
# Games: 271; Score: 29; Max Score: 36
# Games: 272; Score: 34; Max Score: 36
# Games: 273; Score: 16; Max Score: 36
# Games: 274; Score: 11; Max Score: 36
# Games: 275; Score: 30; Max Score: 36
# Games: 276; Score: 9; Max Score: 36
# Games: 277; Score: 30; Max Score: 36
# Games: 278; Score: 13; Max Score: 36
# Games: 279; Score: 34; Max Score: 36
# Games: 280; Score: 13; Max Score: 36
# Games: 281; Score: 36; Max Score: 36
# Games: 282; Score: 19; Max Score: 36
# Games: 283; Score: 4; Max Score: 36
# Games: 284; Score: 3; Max Score: 36
# Games: 285; Score: 17; Max Score: 36
# Games: 286; Score: 22; Max Score: 36
# Games: 287; Score: 74; Max Score: 74
# Games: 288; Score: 9; Max Score: 74
# Games: 289; Score: 9; Max Score: 74
# Games: 290; Score: 6; Max Score: 74
# Games: 291; Score: 22; Max Score: 74
# Games: 292; Score: 8; Max Score: 74
# Games: 293; Score: 38; Max Score: 74
# Games: 294; Score: 27; Max Score: 74
# Games: 295; Score: 36; Max Score: 74
# Games: 296; Score: 4; Max Score: 74
# Games: 297; Score: 13; Max Score: 74
# Games: 298; Score: 21; Max Score: 74
# Games: 299; Score: 2; Max Score: 74
# Games: 300; Score: 37; Max Score: 74
# Save Qvals

# %% [markdown]
# #### Graphing the progression of the agent's score (will only work if model was just trained):

# %%
# Plot the scores
plt.plot(scores, label='Scores')

# Calculate the moving average
window_size = 25
moving_avg = [sum(scores[i:i+window_size])/window_size for i in range(len(scores)-window_size+1)]

# Plot the moving average
plt.plot(moving_avg, label='Moving Average (prev 25)')

# Add labels and title
plt.xlabel('Episode')
plt.ylabel('Score')
plt.title('Scores and Moving Average')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# #### Saving and loading the trained agent
# The code above above saves the trained agent as a pkl file. You can use the cell below to load the trained agent and run it (so you don't have to re-train it).
# Keep in mind, the model does do a bad job every now and then. If it dies after a few apples, just re-run the game loop, and it will most likely perform better.

# %%
agent.load()
pygame.init()
FRAMESPEED = 50 # slower frame speed for visualization
GameLoop(agent, DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE, FRAMESPEED, draw=True)
pygame.quit()
